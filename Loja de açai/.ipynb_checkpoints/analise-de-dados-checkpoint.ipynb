# %% [markdown]
# # Análise de dados com Python

# %% [markdown]
# ## Biblioteca

# %%
import pandas as pd

# %% [markdown]
# ## Carregando dados

# %%
dados = pd.read_excel("vendas.xlsx")

# %% [markdown]
# ## Análise exploratória

# %%
# Mostrar as primeiras linhas

dados.head()
# Out:
#   id_pedido       data    loja          cidade          estado    regiao  \
# 0   PED1994 2020-01-01  Loja 4          Santos       São Paulo   Sudeste
# 1   PED2246 2020-01-01  Loja 6   Florianópolis  Santa Catarina       Sul
# 2   PED3876 2020-01-01  Loja 3  Rio de Janeiro  Rio de Janeiro   Sudeste
# 3   PED4352 2020-01-01  Loja 1       Fortaleza           Ceará  Nordeste
# 4   PED8633 2020-01-01  Loja 5       São Paulo       São Paulo   Sudeste
#
#   tamanho     local_consumo  preco forma_pagamento  ano_mes
# 0   300ml  Consumo no local      5        Dinheiro  2020-01
# 1   500ml  Consumo no local     11          Débito  2020-01
# 2   300ml          Delivery      7         Crédito  2020-01
# 3  1000ml  Consumo no local      7          Débito  2020-01
# 4   200ml          Delivery      9         Crédito  2020-01

# %%
# Mostrar as últimas linhas

dados.tail()
# Out:
#       id_pedido       data    loja          cidade          estado    regiao  \
# 69995  PED67084 2022-12-31  Loja 6   Florianópolis  Santa Catarina       Sul
# 69996  PED67857 2022-12-31  Loja 3  Rio de Janeiro  Rio de Janeiro   Sudeste
# 69997  PED69171 2022-12-31  Loja 4          Santos       São Paulo   Sudeste
# 69998  PED69229 2022-12-31  Loja 4          Santos       São Paulo   Sudeste
# 69999  PED69356 2022-12-31  Loja 1       Fortaleza           Ceará  Nordeste
#
#       tamanho     local_consumo  preco forma_pagamento  ano_mes
# 69995   500ml  Consumo no local     11         Crédito  2022-12
# 69996   200ml  Consumo no local      7             Pix  2022-12
# 69997   500ml  Consumo no local      5        Dinheiro  2022-12
# 69998   300ml  Consumo no local      9             Pix  2022-12
# 69999   300ml          Delivery      9             Pix  2022-12

# %%
# Verificando a quantidade de linhas e colunas

dados.shape
# Out:
# (70000, 11)

# %%
# Verificando os tipos de dados

dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id_pedido        70000 non-null  object
#  1   data             70000 non-null  datetime64[ns]
#  2   loja             70000 non-null  object
#  3   cidade           70000 non-null  object
#  4   estado           70000 non-null  object
#  5   regiao           70000 non-null  object
#  6   tamanho          70000 non-null  object
#  7   local_consumo    70000 non-null  object
#  8   preco            70000 non-null  int64
#  9   forma_pagamento  70000 non-null  object
#  10  ano_mes          70000 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(9)
# memory usage: 5.9+ MB

# %%
dados.preco
# Out:
# 0         5
# 1        11
# 2         7
# 3         7
# 4         9
#          ..
# 69995    11
# 69996     7
# 69997     5
# 69998     9
# 69999     9
# Name: preco, Length: 70000, dtype: int64

# %% [markdown]
# ## Gerando estatísticas

# %%
dados.preco.describe()
# Out:
# count    70000.000000
# mean         8.355200
# std          2.653061
# min          5.000000
# 25%          7.000000
# 50%          7.000000
# 75%         11.000000
# max         13.000000
# Name: preco, dtype: float64

# %% [markdown]
# ## Análises

# %%
# Total e vendas por loja

dados.loja.value_counts()
# Out:
# loja
# Loja 4    13483
# Loja 6    13075
# Loja 1    12344
# Loja 5    12177
# Loja 3    10603
# Loja 2     8318
# Name: count, dtype: int64

# %%
# Total de vendas por cidade

dados.cidade.value_counts()
# Out:
# cidade
# Santos            13483
# Florianópolis     13075
# Fortaleza         12344
# São Paulo         12177
# Rio de Janeiro    10603
# Niterói            8318
# Name: count, dtype: int64

# %%
# Total de vendas por forma de pagamento

dados.forma_pagamento.value_counts()
# Out:
# forma_pagamento
# Crédito     26063
# Débito      20427
# Dinheiro    14709
# Pix          8801
# Name: count, dtype: int64

# %% [markdown]
# ## Agrupamento de dados

# %%
#faturamento por loja

dados.groupby("loja").preco.sum()
# Out:
# loja
# Loja 1    103162
# Loja 2     69592
# Loja 3     88357
# Loja 4    112379
# Loja 5    102189
# Loja 6    109185
# Name: preco, dtype: int64

# %%
# Faturamento por estado

dados.groupby(["estado", "cidade", "loja"]).preco.sum().to_excel("faturamento-estado-cidade.xlsx")
# dados.groupby("estado").preco.mean().to_frame()
# dados.groupby("estado").preco.min().to_frame()

# %% [markdown]
# ## Visualização de dados

# %%
# !pip install plotly_express
# Out:
# Collecting plotly_express
#   Downloading plotly_express-0.4.1-py2.py3-none-any.whl (2.9 kB)
# Requirement already satisfied: pandas>=0.20.0 in c:\users\kaues\anaconda3\lib\site-packages (from plotly_express) (2.0.3)
# Requirement already satisfied: plotly>=4.1.0 in c:\users\kaues\anaconda3\lib\site-packages (from plotly_express) (5.9.0)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\kaues\anaconda3\lib\site-packages (from plotly_express) (0.14.0)
# Requirement already satisfied: scipy>=0.18 in c:\users\kaues\anaconda3\lib\site-packages (from plotly_express) (1.11.1)
# Requirement already satisfied: patsy>=0.5 in c:\users\kaues\anaconda3\lib\site-packages (from plotly_express) (0.5.3)
# Requirement already satisfied: numpy>=1.11 in c:\users\kaues\anaconda3\lib\site-packages (from plotly_express) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kaues\anaconda3\lib\site-packages (from pandas>=0.20.0->plotly_express) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kaues\anaconda3\lib\site-packages (from pandas>=0.20.0->plotly_express) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\kaues\anaconda3\lib\site-packages (from pandas>=0.20.0->plotly_express) (2023.3)
# Requirement already satisfied: six in c:\users\kaues\anaconda3\lib\site-packages (from patsy>=0.5->plotly_express) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\kaues\anaconda3\lib\site-packages (from plotly>=4.1.0->plotly_express) (8.2.2)
# Requirement already satisfied: packaging>=21.3 in c:\users\kaues\anaconda3\lib\site-packages (from statsmodels>=0.9.0->plotly_express) (23.1)
# Installing collected packages: plotly_express
# Successfully installed plotly_express-0.4.1

# %%
import plotly_express as px

# %%
grafico = px.histogram(dados, x='cidade', y='preco', title="Vendas por loja", text_auto=True, color="forma_pagamento")

# %%
grafico.show()
# Out:
# <div>                            <div id="525d779e-ce6b-4dcd-962a-3f09181e3bf3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("525d779e-ce6b-4dcd-962a-3f09181e3bf3")) {                    Plotly.newPlot(                        "525d779e-ce6b-4dcd-962a-3f09181e3bf3",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"forma_pagamento=Dinheiro<br>cidade=%{x}<br>sum of preco=%{y}<extra></extra>","legendgroup":"Dinheiro","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Dinheiro","offsetgroup":"Dinheiro","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Santos","Santos","Santos","Santos","Fortaleza","S\u00e3o Paulo","Niter\u00f3i","S\u00e3o Paulo","Rio de Janeiro","S\u00e3o Paulo","Niter\u00f3i","Santos","Rio de Janeiro","Santos","Santos","Santos","Rio de Janeiro","Fortaleza","Santos","Niter\u00f3i","Santos","S\u00e3o Paulo","Fortaleza","Santos","S\u00e3o Paulo","Fortaleza","Florian\u00f3polis","Rio de Janeiro","Santos","Santos","Niter\u00f3i","Florian\u00f3polis","S\u00e3o Paulo","Fortaleza","S\u00e3o Paulo","Fortaleza","Santos","Florian\u00f3polis","S\u00e3o Paulo","Rio de Janeiro","S\u00e3o Paulo","Rio de Janeiro","Rio de Janeiro","Rio de Janeiro","Niter\u00f3i","Santos","Rio de Janeiro","Rio de Janeiro","Rio de Janeiro","Santos","S\u00e3o Paulo","Santos","Rio de Janeiro","Rio de Janeiro","S\u00e3o Paulo","Santos","Fortaleza","Santos","S\u00e3o Paulo","Santos","Niter\u00f3i","Rio de Janeiro","Rio de Janeiro","Santos","Fortaleza","Santos","S\u00e3o Paulo","S\u00e3o Paulo","Santos","Fortaleza","S\u00e3o Paulo","S\u00e3o Paulo","Niter\u00f3i","Rio de Janeiro","Rio de Janeiro","Santos","Santos","S\u00e3o Paulo","Niter\u00f3i","Santos","Rio de Janeiro","Rio de Janeiro","Fortaleza","S\u00e3o Paulo","Niter\u00f3i","Santos","Fortaleza","Rio de Janeiro","Santos","Fortaleza","Niter\u00f3i","Florian\u00f3polis","Fortaleza","Niter\u00f3i","Rio de Janeiro","S\u00e3o Paulo","Rio de Janeiro","S\u00e3o Paulo","Niter\u00f3i","S\u00e3o Paulo","Rio de Janeiro","Fortaleza","S\u00e3o Paulo","Rio de Janeiro","Rio de Janeiro","Niter\u00f3i","Santos","Florian\u00f3polis","Fortaleza","Santos","Florian\u00f3polis","Santos","Rio de Janeiro","Florian\u00f3polis","Fortaleza","Fortaleza","S\u00e3o Paulo","S\u00e3o Paulo","Rio de Janeiro","Santos","S\u00e3o Paulo","Niter\u00f3i","Santos","Florian\u00f3polis","Florian\u00f3polis","S\u00e3o Paulo","S\u00e3o Paulo","Niter\u00f3i","Rio de Janeiro","Florian\u00f3polis","Florian\u00f3polis","S\u00e3o Paulo","Niter\u00f3i","Florian\u00f3polis","Santos","Santos","Florian\u00f3polis","Rio de Janeiro","Niter\u00f3i","S\u00e3o Paulo","Santos","Rio de Janeiro","S\u00e3o Paulo","Rio de Janeiro","S\u00e3o Paulo","Niter\u00f3i","Fortaleza","S\u00e3o Paulo","Fortaleza","Fortaleza","Rio de Janeiro","Santos","Santos","Santos","Santos","Santos","Rio de Janeiro","Fortaleza","Santos","Fortaleza","Santos","Santos","Fortaleza","Fortaleza","S\u00e3o Paulo","Santos","S\u00e3o Paulo","Fortaleza","Santos","Florian\u00f3polis","S\u00e3o Paulo","Niter\u00f3i","Florian\u00f3polis","S\u00e3o Paulo","S\u00e3o Paulo","Niter\u00f3i","Santos","Florian\u00f3polis","Rio de Janeiro","Rio de Janeiro","S\u00e3o Paulo","Rio de Janeiro","Fortaleza","Fortaleza","S\u00e3o Paulo","Niter\u00f3i","Fortaleza","Rio de Janeiro","Santos","Florian\u00f3polis","Santos","S\u00e3o Paulo","S\u00e3o Paulo","Santos","Fortaleza","Fortaleza","Rio de Janeiro","Santos","Fortaleza","Fortaleza","Santos","Niter\u00f3i","S\u00e3o Paulo","Florian\u00f3polis","S\u00e3o Paulo","Florian\u00f3polis","Rio de Janeiro","Florian\u00f3polis","Rio de Janeiro","Santos","Florian\u00f3polis","Santos","S\u00e3o Paulo","Fortaleza","Florian\u00f3polis","Niter\u00f3i","Niter\u00f3i" ...

# %%
grafico.write_html('grafico.html')

# %% [markdown]
# ## Lista

# %%
nomes = ["kaue", "pietro", "lorenzo"]

# %% [markdown]
# ## Estrutura de repetição

# %%
for i in nomes
