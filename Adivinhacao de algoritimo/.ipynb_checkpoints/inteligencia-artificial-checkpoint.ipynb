# %% [markdown]
# # Projeto Inteligência Artificial - Machine Learning

# %% [markdown]
# ## Coletar os dados

# %%
import yfinance as yf

# %%
codigo = input("Digite o código da ação: ")
dados = yf.Ticker(codigo).history("2y")

dados.head()
# Out:
# Digite o código da ação: PETR4.SA
#                                 Open       High        Low      Close  \
# Date
# 2022-01-26 00:00:00-03:00  15.079558  15.518813  15.079558  15.337676
# 2022-01-27 00:00:00-03:00  15.509753  15.686360  15.020686  15.342203
# 2022-01-28 00:00:00-03:00  15.305975  15.555037  14.590490  14.735398
# 2022-01-31 00:00:00-03:00  14.717283  14.943703  14.522562  14.649357
# 2022-02-01 00:00:00-03:00  14.649356  15.088611  14.468222  14.943703
#
#                               Volume  Dividends  Stock Splits
# Date
# 2022-01-26 00:00:00-03:00   98679900        0.0           0.0
# 2022-01-27 00:00:00-03:00   90631000        0.0           0.0
# 2022-01-28 00:00:00-03:00  117400500        0.0           0.0
# 2022-01-31 00:00:00-03:00   62450300        0.0           0.0
# 2022-02-01 00:00:00-03:00   57315200        0.0           0.0

# %% [markdown]
# ## Tratamento de dados

# %%
# Resetar o indice

treinamento = dados.reset_index()

# Extraindo so a data e atribuindo ao date

treinamento["Date"] = treinamento["Date"].dt.date

#Filtrar os meus dados

colunas = ["Date", "Close"]
treinamento = treinamento[colunas]

# Alterar o nome das colunas

treinamento.columns = ["ds", "y"]

treinamento
# Out:
#              ds          y
# 0    2022-01-26  15.337676
# 1    2022-01-27  15.342203
# 2    2022-01-28  14.735398
# 3    2022-01-31  14.649357
# 4    2022-02-01  14.943703
# ..          ...        ...
# 495  2024-01-22  37.700001
# 496  2024-01-23  38.169998
# 497  2024-01-24  37.880001
# 498  2024-01-25  39.279999
# 499  2024-01-26  39.500000
#
# [500 rows x 2 columns]

# %% [markdown]
# ## Criando e treinando o modelo de Machine Learning

# %%
# !pip install prophet
# Out:
# Collecting prophet
#   Obtaining dependency information for prophet from https://files.pythonhosted.org/packages/24/2b/834e9a347f2f0161e32a3c6125b8a1ebdf6ac33199a0ed3a0bdf1f0c296f/prophet-1.1.5-py3-none-win_amd64.whl.metadata
#   Downloading prophet-1.1.5-py3-none-win_amd64.whl.metadata (3.6 kB)
# Collecting cmdstanpy>=1.0.4 (from prophet)
#   Obtaining dependency information for cmdstanpy>=1.0.4 from https://files.pythonhosted.org/packages/e8/e2/2ddc273e726680a3c816f9a05c6726d57d61820fa7ab4753ed282d0a8bbe/cmdstanpy-1.2.0-py3-none-any.whl.metadata
#   Downloading cmdstanpy-1.2.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\kaues\anaconda3\lib\site-packages (from prophet) (1.24.3)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\users\kaues\anaconda3\lib\site-packages (from prophet) (3.7.2)
# Requirement already satisfied: pandas>=1.0.4 in c:\users\kaues\anaconda3\lib\site-packages (from prophet) (2.0.3)
# Collecting holidays>=0.25 (from prophet)
#   Obtaining dependency information for holidays>=0.25 from https://files.pythonhosted.org/packages/ca/41/b78b8e03730c0f7b8d7a16bc8bc107406a2ec968c2dc40358d4a6e59da1b/holidays-0.41-py3-none-any.whl.metadata
#   Downloading holidays-0.41-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: tqdm>=4.36.1 in c:\users\kaues\anaconda3\lib\site-packages (from prophet) (4.65.0)
# Collecting importlib-resources (from prophet)
#   Obtaining dependency information for importlib-resources from https://files.pythonhosted.org/packages/93/e8/facde510585869b5ec694e8e0363ffe4eba067cb357a8398a55f6a1f8023/importlib_resources-6.1.1-py3-none-any.whl.metadata
#   Downloading importlib_resources-6.1.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting stanio~=0.3.0 (from cmdstanpy>=1.0.4->prophet)
#   Obtaining dependency information for stanio~=0.3.0 from https://files.pythonhosted.org/packages/26/01/e2579afa3ad1eade8b54bf5b9e45790d219681b1f8f97edbd2f18c4e1a7d/stanio-0.3.0-py3-none-any.whl.metadata
#   Downloading stanio-0.3.0-py3-none-any.whl.metadata (963 bytes)
# Requirement already satisfied: python-dateutil in c:\users\kaues\anaconda3\lib\site-packages (from holidays>=0.25->prophet) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kaues\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\kaues\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kaues\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\kaues\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\kaues\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\kaues\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\kaues\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kaues\anaconda3\lib\site-packages (from pandas>=1.0.4->prophet) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\kaues\anaconda3\lib\site-packages (from pandas>=1.0.4->prophet) (2023.3)
# Requirement already satisfied: colorama in c:\users\kaues\anaconda3\lib\site-packages (from tqdm>=4.36.1->prophet) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\kaues\anaconda3\lib\site-packages (from python-dateutil->holidays>=0.25->prophet) (1.16.0)
# Downloading prophet-1.1.5-py3-none-win_amd64.whl (13.3 MB)
#    ---------------------------------------- 0.0/13.3 MB ? eta -:--:--
#    ---------------------------------------- 0.1/13.3 MB 3.3 MB/s eta 0:00:05
#    - -------------------------------------- 0.4/13.3 MB 4.6 MB/s eta 0:00:03
#    - -------------------------------------- 0.6/13.3 MB 5.8 MB/s eta 0:00:03
#    --- ------------------------------------ 1.2/13.3 MB 6.7 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.6/13.3 MB 7.2 MB/s eta 0:00:02
#    ------ --------------------------------- 2.1/13.3 MB 7.8 MB/s eta 0:00:02
#    ------- -------------------------------- 2.5/13.3 MB 8.1 MB/s eta 0:00:02
#    -------- ------------------------------- 3.0/13.3 MB 8.3 MB/s eta 0:00:02
#    --------- ------------------------------ 3.1/13.3 MB 8.4 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.5/13.3 MB 7.6 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.9/13.3 MB 7.8 MB/s eta 0:00:02
#    ------------ --------------------------- 4.3/13.3 MB 7.8 MB/s eta 0:00:02
#    -------------- ------------------------- 4.7/13.3 MB 8.0 MB/s eta 0:00:02
#    --------------- ------------------------ 5.2/13.3 MB 8.1 MB/s eta 0:00:02
#    ---------------- ----------------------- 5.6/13.3 MB 8.2 MB/s eta 0:00:01
#    ------------------ --------------------- 6.1/13.3 MB 8.3 MB/s eta 0:00:01
#    ------------------- -------------------- 6.6/13.3 MB 8.4 MB/s eta 0:00:01
#    --------------------- ------------------ 7.0/13.3 MB 8.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 7.5/13.3 MB 8.5 MB/s eta 0:00:01
#    ----------------------- ---------------- 8.0/13.3 MB 8.6 MB/s eta 0:00:01
#    ------------------------- -------------- 8.4/13.3 MB 8.7 MB/s eta 0:00:01
#    -------------------------- ------------- 8.9/13.3 MB 8.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 9.4/13.3 MB 8.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 9.8/13.3 MB 8.8 MB/s eta 0:00:01
#    ------------------------------ --------- 10.3/13.3 MB 9.0 MB/s eta 0:00:01
#    -------------------------------- ------- 10.8/13.3 MB 9.2 MB/s eta 0:00:01
#    --------------------------------- ------ 11.2/13.3 MB 9.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.7/13.3 MB 9.4 MB/s eta 0:00:01
#    ------------------------------------ --- 12.2/13.3 MB 9.4 MB/s eta 0:00:01
#    ------------------------------------- -- 12.7/13.3 MB 9.4 MB/s eta 0:00:01
#    ---------------------------------------  13.1/13.3 MB 9.4 MB/s eta 0:00:01
#    ---------------------------------------  13.3/13.3 MB 9.4 MB/s eta 0:00:01
#    ---------------------------------------- 13.3/13.3 MB 9.2 MB/s eta 0:00:00
# Downloading cmdstanpy-1.2.0-py3-none-any.whl (93 kB)
#    ---------------------------------------- 0.0/93.0 kB ? eta -:--:--
#    ---------------------------------------- 93.0/93.0 kB 5.2 MB/s eta 0:00:00
# Downloading holidays-0.41-py3-none-any.whl (913 kB)
#    ---------------------------------------- 0.0/913.1 kB ? eta -:--:--
#    -------------------- ------------------- 471.0/913.1 kB 9.8 MB/s eta 0:00:01
#    ---------------------------------------- 913.1/913.1 kB 9.6 MB/s eta 0:00:00
# Downloading importlib_resources-6.1.1-py3-none-any.whl (33 kB)
# Downloading stanio-0.3.0-py3-none-any.whl (6.2 kB)
# Installing collected packages: stanio, importlib-resources, holidays, cmdstanpy, prophet
# Successfully installed cmdstanpy-1.2.0 holidays-0.41 importlib-resources-6.1.1 prophet-1.1.5 stanio-0.3.0

# %%
from prophet import Prophet

# %%
# Criar o modelo

modelo = Prophet()

# %%
# Treinar o modelo

modelo.fit(treinamento)
# Out:
# 15:25:53 - cmdstanpy - INFO - Chain [1] start processing
# 15:25:53 - cmdstanpy - INFO - Chain [1] done processing

# %% [markdown]
# # Gerando previsões

# %%
periodo = modelo.make_future_dataframe(90)

# %%
previsoes = modelo.predict(periodo)

# %%
previsoes.tail()
# Out:
#             ds      trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 500 2024-01-27  40.184941   37.914673   40.146858    40.184941    40.184941
# 501 2024-01-28  40.262560   37.964717   40.193778    40.262560    40.262560
# 502 2024-01-29  40.340178   38.224352   40.650774    40.340178    40.340178
# 503 2024-01-30  40.417797   38.316941   40.683001    40.417797    40.417797
# 504 2024-01-31  40.495415   38.585270   40.831113    40.495415    40.495415
#
#      additive_terms  additive_terms_lower  additive_terms_upper    weekly  \
# 500       -1.176380             -1.176380             -1.176380 -0.205463
# 501       -1.156059             -1.156059             -1.156059 -0.205463
# 502       -0.892251             -0.892251             -0.892251  0.035931
# 503       -0.865524             -0.865524             -0.865524  0.038546
# 504       -0.788962             -0.788962             -0.788962  0.089710
#
#      weekly_lower  weekly_upper    yearly  yearly_lower  yearly_upper  \
# 500     -0.205463     -0.205463 -0.970917     -0.970917     -0.970917
# 501     -0.205463     -0.205463 -0.950596     -0.950596     -0.950596
# 502      0.035931      0.035931 -0.928182     -0.928182     -0.928182
# 503      0.038546      0.038546 -0.904070     -0.904070     -0.904070
# 504      0.089710      0.089710 -0.878672     -0.878672     -0.878672
#
#      multiplicative_terms  multiplicative_terms_lower  \
# 500                   0.0                         0.0
# 501                   0.0                         0.0
# 502                   0.0                         0.0
# 503                   0.0                         0.0
# 504                   0.0                         0.0
#
#      multiplicative_terms_upper       yhat
# 500                         0.0  39.008561
# 501                         0.0  39.106501
# 502                         0.0  39.447927
# 503                         0.0  39.552273
# 504                         0.0  39.706453
